# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_predict, KFold

sns.set_style("whitegrid")
print("Libraries loaded ✓")
# Out:
# Libraries loaded ✓

# %%
df = pd.read_excel(
    "../data/Surface_Tension_Aim3_Full.xlsx",
    sheet_name="Surface_Tension_Dataset",
    header=3  # row 4 is the column headers
)

print(f"Shape: {df.shape}")
print(f"\nColumns: {list(df.columns)}")
df.head()
# Out:
# Shape: (100, 16)
#
# Columns: ['IL ID', 'IL Name', 'Cation\nFamily', 'Anion\nFamily', 'Cation SMILES', 'Anion SMILES', 'F Count\n(Cat)', 'F Count\n(An)', 'F Total', 'MW Cat\n(g/mol)', 'MW An\n(g/mol)', 'MW Total\n(g/mol)', 'Surface\nTension (mN/m)', 'Temp (K)', 'Data Quality', 'Source']
#     IL ID       IL Name Cation\nFamily Anion\nFamily  \
# 0  IL-001   [Bmim][FAP]    Imidazolium           FAP
# 1  IL-002   [Emim][FAP]    Imidazolium           FAP
# 2  IL-003   [Hmim][FAP]    Imidazolium           FAP
# 3  IL-004           FIL    Imidazolium         BNFSI
# 4  IL-005  [Hmim][NTf2]    Imidazolium          TFSI
#
#                       Cation SMILES  \
# 0                      CCCCn1ccnc1C
# 1                   CCn1cc[n+](C)c1
# 2               CCCCCCn1cc[n+](C)c1
# 3  CCn1ccnc1CC(F)(F)C(F)(F)C(F)(F)F
# 4               CCCCCCn1cc[n+](C)c1
#
#                                         Anion SMILES  F Count\n(Cat)  \
# 0            F[P-](F)(F)(C(F)(F)F)(C(F)(F)F)C(F)(F)F             0.0
# 1            F[P-](F)(F)(C(F)(F)F)(C(F)(F)F)C(F)(F)F             0.0
# 2            F[P-](F)(F)(C(F)(F)F)(C(F)(F)F)C(F)(F)F             0.0
# 3  O=S(=O)([N-]S(=O)(=O)C(F)(F)(F)C(F)(F)F)C(F)(F...            13.0
# 4             O=S(=O)([N-]S(=O)(=O)C(F)(F)F)C(F)(F)F             0.0
#
#    F Count\n(An)  F Total  MW Cat\n(g/mol)  MW An\n(g/mol)  MW Total\n(g/mol)  \
# 0           15.0     15.0            139.2           445.0              584.2
# 1           15.0     15.0            111.2           445.0              556.2
# 2           15.0     15.0            167.3           445.0              612.3
# 3           18.0     31.0            350.0           530.0              880.0
# 4            6.0      6.0            167.3           280.2              447.5
#
#    Surface\nTension (mN/m)  Temp (K)     Data Quality  \
# 0                     32.4       298  Internal (1.0×)
# 1                     34.3       298  Internal (1.0×)
# 2                     31.5       298  Internal (1.0×)
# 3                     24.5       298  Internal (1.0×)
# 4                     31.2       298  Internal (1.0×)
#
#                                    Source
# 0  Wang et al. 2019 ACS Appl. Nano Mater.
# 1       Bingchen diss. Table 3 (Li group)
# 2       Bingchen diss. Table 3 (Li group)
# 3  Wang et al. 2020 ACS Appl. Nano Mater.
# 4  Wang et al. 2020 ACS Appl. Nano Mater.
